# %%
print('My name is Phap') #string ->str
# Out:
# My name is Phap

# %%
print(101) # integer ->int
# Out:
# 101

# %%
print(10.05)#float -> float
# Out:
# 10.05

# %%
print(True) # blooean ->bool
print(False)
# Out:
# True
# False

# %% [markdown]
# # Toán tử

# %%
a = 10
b = 5
c = 2.5
d = "Python"
e = "Fundamental"

# %% [markdown]
# ## Toán tử cộng

# %%
print(a + b)
print(a + c)
# Out:
# 15
# 12.5

# %%
print(d + e)
# Out:
# PythonFundamental

# %%
print(a+True) #True = 1
print(a+False) #False = 0
# Out:
# 11
# 10

# %% [markdown]
# ## Toán tử trừ

# %%
print(a-b)
# Out:
# 5

# %%
print(d-e) # chữ ko dc trừ chữ
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(d-e) # chữ ko dc trừ chữ
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %% [markdown]
# ## Toán tử nhân

# %%
print(a * b)
print(d * 3) #chữ nhân 3 sẽ tạo 3 chữ tiếp nối
# Out:
# 50
# PythonPythonPython

# %% [markdown]
# ## Toán tử chia

# %%
print(a / b) #kết quả của phép chia luôn là float - >(10/5=2.0)
# Out:
# 2.0

# %% [markdown]
# ## Chia lấy dư

# %%
print(b % 2) #chia lấy dưa tức lấy 5/2 sẽ dư ra 1
print (b//2) # kết quả của phép chia lấy phần nguyên ( 5/2 sẽ dược 2) kiểu int
# Out:
# 1
# 2

# %% [markdown]
# ## Lũy thừa

# %%
print ( 2**3)
# Out:
# 8

# %% [markdown]
# ## Toán tử quan hệ

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:4d66f52d-84e4-45f8-807f-15a597cac8cc.png)![image.png](attachment:b5b88736-f5a8-42fd-bafb-145cc0c13c50.png)

# %% [markdown]
# ## Phép gán

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
salary = 1000
salary  = salary + 200
print(salary)
# Out:
# 1200

# %%
salary = 1000
salary += 200 
print(salary)
# Out:
# 1200

# %% [markdown]
# ## Toán tử logic

# %% [markdown]
# ![image.png](attachment:98ba6e30-5446-474f-9a05-b8a6ddde194d.png)![image.png](attachment:6d88e78e-ee0f-4f52-9eaa-66a4afcd0114.png)

# %% [markdown]
# ![image.png](attachment:image.png)
